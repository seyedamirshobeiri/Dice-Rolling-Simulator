# %%
#import libarary
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#take a ready number
a=int(input('if you are ready enter 1 :'))

#loop if user is ready
if (a == 1):
    #random number between 1 - 6
    n=random.randint(1,6)
    
    #load dice
    b=str(n)+'.jpg'
    plt.imshow(mpimg.imread(b))
else:
    print('Oh,That is bad !!!!!')
# Out:
# if you are ready enter 1 :1
